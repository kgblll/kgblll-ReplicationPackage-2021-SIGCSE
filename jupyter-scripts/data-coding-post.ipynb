# %%
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt

# %%
preguntas_post = {
    "¿Cuál es tu sexo?": {
        "tipo": "opcion_no_evaluable",
        "enunciado": "¿Cuál es tu sexo?"
    },
    "Curso":{
        "tipo": "opcion_no_evaluable",
        "enunciado": "Marca cuál es tu curso"
    },
    "Dispositivo electrónico": {
        "tipo": "opcion_no_evaluable",
        "enunciado": "¿En qué tipo de dispositivo electrónico vas a realizar el test?"

    },
    
    "Pregunta 1": {
        "tipo": "abierta",
        "enunciado": "Describe brevemente qué crees que es la Inteligencia Artificial"
    },
    "Pregunta 2": {
        "tipo": "opcion",
        "enunciado": "Una parte importante de los algoritmos sobre los que se sustentan los sistemas de inteligencia artificial (IA) actuales se desarrollaron:",
        "respuestas": {
            "En la Edad Media": 0,
            "Durante el Renacimiento": 0,
            "En el siglo XX": 1,
            "El año pasado": 0
        },    
    },
    "Pregunta 3": {
        "tipo": "opcion",
        "enunciado": "Cuando al realizar un dibujo en una aplicación de reconocimiento de imágenes que utiliza técnicas de aprendizaje automático o machine learning (ML), el sistema es capaz de reconocer lo que estás pintando (por ejemplo, una tortuga), esto se debe a: ",
        "respuestas": {
            "Que has dibujado una tortuga muy parecida a la tortuga que dibujaron los creadores del sistema durante su entrenamiento.": 0,
            "Que tu dibujo es muy parecido al que realizó el jugador anterior que tuvo que pintar una tortuga.": 0,
            "Que tu dibujo es igual a la típica tortuga que aparece en las búsquedas de Google Imágenes.": 0,
            "Que el sistema ha reconocido en tu dibujo patrones similares a los de los dibujos de tortugas con los que fue entrenado.": 1
        }
    },
    "Pregunta 4": {
        "tipo": "opcion",
        "enunciado": "Cuando un sistema de inteligencia artificial (IA) ofrece resultados que discriminan en términos, por ejemplo, de sexo, esto se suele deber a:",
        "respuestas": {
            "Que los datos que se usaron para entrenar al sistema no estaban equilibrados, es decir, que se utilizaron muchos más datos correspondientes a hombres que a mujeres, o viceversa.": 1,
            "Que los desarrolladores del sistema tenían sesgos sexistas.": 0,
            "Que el sistema está diseñado para ser utilizado por hombres en mayor  medida que por mujeres, o viceversa.": 0,
            "Que el sistema refleja la realidad sexista de la naturaleza humana.": 0
        }
    },
    "Pregunta 5": {
        "tipo": "opcion",
        "enunciado": "Cuando implementamos técnicas de aprendizaje automático o machine learning (ML) en un sistema de reconocimiento de texto:",
        "respuestas": {
            "Presentamos al ordenador un conjunto de textos de ejemplo y éste, después de procesarlos, es capaz de reconocer únicamente los textos que coincidan exactamente con dichos ejemplos.": 0,
            "Presentamos al ordenador un conjunto de textos de ejemplo y éste, después de procesarlos, es capaz de reconocer textos parecidos a dichos ejemplos (es decir, de reconocer textos nuevos que no ha visto anteriormente).": 1,
            "Presentamos al ordenador un conjunto de textos de ejemplo y éste, después de procesarlos, es capaz de reconocer cualquier texto que le presentemos.": 0,
            "Presentamos al ordenador un conjunto de textos de ejemplo y éste, después de procesarlos, es capaz de reconocer cualquier texto, imagen o sonido que le presentemos.": 0
        }
    },
     "Pregunta 6": {
        "tipo": "opcion",
        "enunciado": "¿Cuál de las siguientes afirmaciones es verdadera al respecto del aprendizaje automático o machine learning (ML)?",
        "respuestas": {
            "Los datos de entrenamiento son fundamentales para el aprendizaje automático, sin datos no es posible hacer aprendizaje automático.": 1,
            "Con el aprendizaje automático los ordenadores aprenden a pensar y pueden reconocer cualquier tipo de dato (texto, imagen, sonido…), de la misma manera que lo hace un ser humano.": 0,
            "Cuantos más datos utilizamos para entrenar un sistema que incorpora aprendizaje automático, peores (más inexactos) son los resultados ofrecidos por dicho sistema.": 0,
            "El aprendizaje automático no necesita datos para funcionar, precisamente porque es automático y no depende de que se le alimente con datos de ningún tipo.": 0
        }
    },
     "Pregunta 7": {
        "tipo": "opcion",
        "enunciado": "¿Cuál de las siguientes estrategias sería más adecuada para enseñar a un ordenador a reconocer la foto de una manzana cualquiera?",
        "respuestas": {
            "Entrenar al ordenador con fotos de perros.": 0,
            "Entrenar al ordenador con varias fotos de distintas manzanas, tomadas en distintos lugares y contextos.": 1,
            "Entrenar al ordenador con varias fotos similares de la misma manzana, tomadas en el mismo sitio.": 0,
            "Entrenar al ordenador con varias copias idénticas de la misma foto de una manzana.": 0
        }
    },
     "Pregunta 8": {
        "tipo": "opcion",
        "enunciado": "¿Cuál de las siguientes afirmaciones es correcta al respecto del aprendizaje automático o machine learning (ML)?",
        "respuestas": {
            "El ML es una técnica que permite entrenar a los ordenadores con datos de ejemplo para que desempeñen ciertas tareas; en vez de tener que programarlos con un conjunto explícito de pasos y reglas a seguir.": 1,
            "El ML implica que los humanos no tendremos que pensar más acerca de cómo resolver los problemas, puesto que los ordenadores pensarán por nosotros (y mejor que nosotros).": 0,
            "El ML implica que ya no es necesario que los humanos aprendan a programar.": 0,
            "El ML sólo puede implementarse en súper-ordenadores con una enorme capacidad de cálculo.": 0
        }
    },
     "Pregunta 9": {
        "tipo": "opcion",
        "enunciado": "¿En cuál de las siguientes tareas, a desempeñar por un ordenador, sería adecuado aplicar técnicas de aprendizaje automático o machine learning (ML)?",
        "respuestas": {
            "Sumar números grandes.": 0,
            "Reconocer si un correo electrónico es spam (correo no deseado).": 1,
            "Contar el número de veces que es pulsada una tecla.": 0,
            "Informar del horario de un determinado comercio en función del día de la semana.": 0
            
        }
    },
     "Pregunta 10": {
        "tipo": "opcion",
        "enunciado": "A la hora de entrenar un ordenador mediante técnicas de aprendizaje automático o machine learning (ML), ¿cuál de las siguientes estrategias es probable que tenga más éxito y funcione mejor?",
        "respuestas": {
            "Recoger un pequeño conjunto de ejemplos; entrenar al sistema; comprobar cómo de bueno (fiable) es el modelo construido; añadir más ejemplos; entrenar de nuevo el sistema; comprobar de nuevo cuán bueno es… y repetir hasta que se consigue un modelo suficientemente bueno.": 1,
            "Más ejemplos de inicio es siempre mejor, así que para comenzar decides recopilar millones de ejemplos de entrenamiento. Comienzas con dicha recolección masiva, y te pasas varios meses recopilando más y más ejemplos. Sólo entonces procedes a entrenar el sistema.": 0
        }
    },
     "Pregunta 11": {
        "tipo": "opcion",
        "enunciado": "Tanto Alicia como Roberto quieren entrenar un sistema de aprendizaje automático o machine learning (ML) que sirva para reconocer si un determinado texto es “feliz/positivo” o “triste/negativo”. Alicia y Roberto siguen dos estrategias distintas de entrenamiento ¿Quién de los dos conseguirá el mejor sistema?",
        "respuestas": {
            "Alicia. Ella ha recopilado 10 ejemplos variados de textos felices/positivos y otros 10 ejemplos variados de textos tristes/negativos.": 1,
            "Roberto. Él ha recopilado 1000 ejemplos de textos felices/positivos y otros 10 ejemplos de textos tristes/negativos.": 0
        }
    },
    "Pregunta 12": {
        "tipo": "likert",
        "enunciado": "El nivel de conocimientos técnicos que se requiere para entender en qué consiste la inteligencia artificial (IA) es demasiado alto para la mayor parte de la población.",
        "respuestas": {
            "Totalmente en desacuerdo.": 1,
            "Algo en desacuerdo.": 0.75,
            "Ni de acuerdo ni en desacuerdo.": 0.5,
            "Algo de acuerdo.": 0.25,
            "Totalmente de acuerdo.": 0
        }
    },
     "Pregunta 13": {
        "tipo": "likert",
        "enunciado": "Si un algoritmo es capaz de predecir el resultado de un partido de fútbol, es muy probable que sea capaz también de predecir el comienzo de la 3ª Guerra Mundial.",
        "respuestas": {
            "Totalmente en desacuerdo.": 1,
            "Algo en desacuerdo.": 0.75,
            "Ni de acuerdo ni en desacuerdo.": 0.5,
            "Algo de acuerdo.": 0.25,
            "Totalmente de acuerdo.": 0
        }
    },
     "Pregunta 14": {
        "tipo": "likert",
        "enunciado": "En menos de 10 años, se desarrollará una inteligencia artificial (IA) tipo Terminator, que amenazará la supervivencia de la humanidad.",
        "respuestas": {
            "Totalmente en desacuerdo.": 1,
            "Algo en desacuerdo.": 0.75,
            "Ni de acuerdo ni en desacuerdo.": 0.5,
            "Algo de acuerdo.": 0.25,
            "Totalmente de acuerdo.": 0
        }
    },
    "Pregunta 15": {
        "tipo": "likert",
        "enunciado": "Como usuario/a, la regulación legal que se apruebe acerca de los dispositivos que utilizan inteligencia artificial (IA) afectará a mi vida:",
        "respuestas": {
            "Totalmente en desacuerdo.": 0,
            "Algo en desacuerdo.": 0.25,
            "Ni de acuerdo ni en desacuerdo.": 0.5,
            "Algo de acuerdo.": 0.75,
            "Totalmente de acuerdo.": 1
        }
    },
    "Pregunta 16": {
        "tipo": "abierta",
        "enunciado": "Describe brevemente cuales son los principales peligros de la Inteligencia Artificial, si conoces alguno de ellos."
    },
    "Pregunta 17": {
        "tipo": "likert",
        "enunciado": "¿Te ha parecido LearningML una  aplicación útil para aprender sobre Inteligencia Artificial?",
        "respuestas": {
            "Totalmente en desacuerdo": 1,
            "En desacuerdo": 2,
            "Ni de acuerdo ni en desacuerdo": 3,
            "De acuerdo": 4,
            "Totalmente de acuerdo": 5
        }
    },
    "Pregunta 18": {
        "tipo": "likert",
        "enunciado": "¿Te ha resultado fácil usar LearningML para programar una aplicación con Inteligencia Artificial?",
        "respuestas": {
            "Me ha resultado muy difícil": 1,
            "Me ha resultado difícil": 2,
            "Una cosa normal, ni fácil ni difícil": 3,
            "Me ha resultado fácil": 4,
            "Me ha resultado muy fácil": 5
        }
    },
    "Pregunta 19": {
        "tipo": "opcion_no_evaluable",
        "enunciado": "¿Qué tipo de proyectos has hecho cuando has probado LearningML?"
    },
    "Pregunta 20": {
        "tipo": "abierta",
        "enunciado": "En un proyecto programado con LearningML, ¿para qué serviría usar el bloque \"clasifica <texto>\"?' "
    },
    "Pregunta 21": {
        "tipo": "abierta",
        "enunciado": "¿Qué propuestas de mejora se te ocurren para la herramienta LearningML?"
    }
    
}

# %%
df_post = pd.read_excel("../data/Post Test IA - Investigación online LML.xlsx")

dict_resultados_post = {}

def isNaN(num):
    return num != num

for index, row in df_post.iterrows():
    dict_resultados_post[row["Código"]] = []
    for pregunta in preguntas_post:
        if preguntas_post[pregunta]["tipo"] == "abierta" or preguntas_post[pregunta]["tipo"] == "opcion_no_evaluable":
            dict_resultados_post[row["Código"]].append(row[pregunta])
        elif preguntas_post[pregunta]["tipo"] == "opcion" or preguntas_post[pregunta]["tipo"] == "likert":
            #print(preguntas_post[pregunta]["respuestas"])
            #print(row[pregunta])
            if(isNaN(row[pregunta])):
                #puntos = 0
                #dict_resultados_post.pop(row["Código"], None)
                puntos = ""
                #break
            else:
                puntos = preguntas_post[pregunta]["respuestas"][row[pregunta]]
            
            dict_resultados_post[row["Código"]].append(puntos)
        else:
            print("tipo de pregunta no contemplada: {}".format(preguntas_post[pregunta]["tipo"]))

# %%
# %store dict_resultados_post
# %store preguntas_post
# Out:
# Stored 'dict_resultados_post' (dict)
# Stored 'preguntas_post' (dict)
